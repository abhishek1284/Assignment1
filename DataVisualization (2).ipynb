# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("sales_data.csv")
data
# Out:
#      Product_ID   Price  Units_Sold     Sales        Date     Category  \
# 0         P0075   47.48        39.0   1851.72   3/28/2023  Electronics
# 1         P0032  375.96        63.0  23685.48   11/2/2023  Accessories
# 2         P0008  130.84        33.0   4317.72    5/7/2023  Accessories
# 3         P0035  447.16        71.0  31748.36  12/28/2023         Food
# 4         P0046  369.39        54.0  19947.06    5/1/2023         Food
# ...         ...     ...         ...       ...         ...          ...
# 1209      P0051  450.58        93.0  41903.94    7/5/2023  Electronics
# 1210      P0096  156.15        11.0   1717.65  11/29/2023  Accessories
# 1211      P0069  443.75        80.0  35500.00   6/13/2023  Accessories
# 1212      P0060  438.51        96.0  42096.96  12/25/2023  Electronics
# 1213      P0060  394.78        28.0  11053.84  10/18/2023         Food
#
#       Discount Store_Location Customer_ID
# 0         15.0     California       C0135
# ...

# %%
data_cleaned= data.dropna()
data_cleaned
# Out:
#      Product_ID   Price  Units_Sold     Sales        Date     Category  \
# 0         P0075   47.48        39.0   1851.72   3/28/2023  Electronics
# 1         P0032  375.96        63.0  23685.48   11/2/2023  Accessories
# 2         P0008  130.84        33.0   4317.72    5/7/2023  Accessories
# 3         P0035  447.16        71.0  31748.36  12/28/2023         Food
# 4         P0046  369.39        54.0  19947.06    5/1/2023         Food
# ...         ...     ...         ...       ...         ...          ...
# 1209      P0051  450.58        93.0  41903.94    7/5/2023  Electronics
# 1210      P0096  156.15        11.0   1717.65  11/29/2023  Accessories
# 1211      P0069  443.75        80.0  35500.00   6/13/2023  Accessories
# 1212      P0060  438.51        96.0  42096.96  12/25/2023  Electronics
# 1213      P0060  394.78        28.0  11053.84  10/18/2023         Food
#
#       Discount Store_Location Customer_ID
# 0         15.0     California       C0135
# ...

# %%
data_cleaned=data_cleaned.drop_duplicates()
data_cleaned
# Out:
#      Product_ID   Price  Units_Sold     Sales        Date     Category  \
# 0         P0075   47.48        39.0   1851.72   3/28/2023  Electronics
# 1         P0032  375.96        63.0  23685.48   11/2/2023  Accessories
# 2         P0008  130.84        33.0   4317.72    5/7/2023  Accessories
# 3         P0035  447.16        71.0  31748.36  12/28/2023         Food
# 4         P0046  369.39        54.0  19947.06    5/1/2023         Food
# ...         ...     ...         ...       ...         ...          ...
# 1209      P0051  450.58        93.0  41903.94    7/5/2023  Electronics
# 1210      P0096  156.15        11.0   1717.65  11/29/2023  Accessories
# 1211      P0069  443.75        80.0  35500.00   6/13/2023  Accessories
# 1212      P0060  438.51        96.0  42096.96  12/25/2023  Electronics
# 1213      P0060  394.78        28.0  11053.84  10/18/2023         Food
#
#       Discount Store_Location Customer_ID
# 0         15.0     California       C0135
# ...

# %%
data_cleaned.to_csv("sales_data.csv", index=False)
data_cleaned
# Out:
#      Product_ID   Price  Units_Sold     Sales        Date     Category  \
# 0         P0075   47.48        39.0   1851.72   3/28/2023  Electronics
# 1         P0032  375.96        63.0  23685.48   11/2/2023  Accessories
# 2         P0008  130.84        33.0   4317.72    5/7/2023  Accessories
# 3         P0035  447.16        71.0  31748.36  12/28/2023         Food
# 4         P0046  369.39        54.0  19947.06    5/1/2023         Food
# ...         ...     ...         ...       ...         ...          ...
# 1209      P0051  450.58        93.0  41903.94    7/5/2023  Electronics
# 1210      P0096  156.15        11.0   1717.65  11/29/2023  Accessories
# 1211      P0069  443.75        80.0  35500.00   6/13/2023  Accessories
# 1212      P0060  438.51        96.0  42096.96  12/25/2023  Electronics
# 1213      P0060  394.78        28.0  11053.84  10/18/2023         Food
#
#       Discount Store_Location Customer_ID
# 0         15.0     California       C0135
# ...

# %%
data_cleaned.head()
# Out:
#   Product_ID   Price  Units_Sold     Sales        Date     Category  Discount  \
# 0      P0075   47.48        39.0   1851.72   3/28/2023  Electronics      15.0
# 1      P0032  375.96        63.0  23685.48   11/2/2023  Accessories       0.0
# 2      P0008  130.84        33.0   4317.72    5/7/2023  Accessories       0.0
# 3      P0035  447.16        71.0  31748.36  12/28/2023         Food      15.0
# 4      P0046  369.39        54.0  19947.06    5/1/2023         Food       0.0
#
#   Store_Location Customer_ID
# 0     California       C0135
# 1          Texas       C0201
# 2       New York       C0027
# 3       Illinois       C0100
# 4       New York       C0038

# %%
data_cleaned.columns
# Out:
# Index(['Product_ID', 'Price', 'Units_Sold', 'Sales', 'Date', 'Category',
#        'Discount', 'Store_Location', 'Customer_ID'],
#       dtype='object')

# %%
# Calculate mean, median, and standard deviation for 'Price' and 'Sales'
price_stats = {
    "mean": data_cleaned["Price"].mean(),
    "median": data_cleaned["Price"].median(),
    "std_dev": data_cleaned["Price"].std()
}

sales_stats = {
    "mean": data_cleaned["Sales"].mean(),
    "median": data_cleaned["Sales"].median(),
    "std_dev": data_cleaned["Sales"].std()
}

print("Price Statistics:", price_stats)
print("Sales Statistics:", sales_stats)
# Out:
# Price Statistics: {'mean': 255.05736408566722, 'median': 255.515, 'std_dev': 142.6130318856418}
# Sales Statistics: {'mean': 13132.587388797365, 'median': 9923.725, 'std_dev': 11204.815559948463}

# %%
# Calculate the correlation between 'Price' and 'Sales'
correlation = data_cleaned["Price"].corr(data_cleaned["Sales"])
print(f"Correlation between Price and Sales: {correlation}")
# Out:
# Correlation between Price and Sales: 0.6605794728747859

# %%
correlation = data_cleaned["Price"].corr(data_cleaned["Sales"])
print(f"Correlation between Price and Sales: {correlation}")
if correlation > 0:
    print("Higher prices are associated with more sales.")
elif correlation < 0:
    print("Higher prices are associated with fewer sales.")
else:
    print("There is no correlation between Price and sales.")
# Out:
# Correlation between Price and Sales: 0.6605794728747859
# Higher prices are associated with more sales.

# %%
plt.figure(figsize=(10, 6))
plt.scatter(data_cleaned["Price"], data_cleaned["Sales"], alpha=0.5, color='b')

# Add titles and labels
plt.title("Scatterplot of Price vs Sales", fontsize=14)
plt.xlabel("Price", fontsize=12)
plt.ylabel("Sales", fontsize=12)

# Show the plot
plt.show()

# %%
# Ensure the 'Date' column is in datetime format
data_cleaned['Date'] = pd.to_datetime(data_cleaned['Date'])

# Sort the data by Date to ensure proper time order
data_cleaned = data_cleaned.sort_values(by='Date')

# Group the data by 'Date' and calculate the sum of sales per day
sales_by_date = data_cleaned.groupby('Date')['Sales'].sum()

# Create a line plot of Sales over time
plt.figure(figsize=(10, 6))
plt.plot(sales_by_date.index, sales_by_date.values, color='b', marker='o')

# Add titles and labels
plt.title("Sales Trend Over Time", fontsize=14)
plt.xlabel("Date", fontsize=12)
plt.ylabel("Sales", fontsize=12)

# Rotate date labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
# Create a figure with two subplots for Price and Sales
plt.figure(figsize=(12, 6))

# Boxplot for Price
plt.subplot(1, 2, 1)
sns.boxplot(data=data_cleaned, x='Price', color='lightblue')
plt.title('Price Distribution')

# Boxplot for Sales
plt.subplot(1, 2, 2)
sns.boxplot(data=data_cleaned, x='Sales', color='lightgreen')
plt.title('Sales Distribution')

# Show the plots
plt.tight_layout()
plt.show()

# %%
#To understand the overall trend of Sales when Price increases or decreases, we need to analyze how the two variables are related. Based on your previous request for correlation analysis (between Price and Sales), we can summarize the following points:

#Correlation: The positive correlation coefficient (0.66) indicates a moderate to strong positive relationship between Price and Sales in the dataset. This suggests that, in general, as Price increases, Sales also tend to increase.

# %%
# Define price bins (adjust these ranges as necessary)
bins = [0, 100, 200, 300, 400, 500, 1000]  # Example price ranges
labels = ['0-100', '101-200', '201-300', '301-400', '401-500', '501+']  # Labels for the bins

# Create a new column for price range
data_cleaned['Price_Range'] = pd.cut(data_cleaned['Price'], bins=bins, labels=labels)

# Group by Price_Range and calculate the average sales for each range
sales_by_price_range = data_cleaned.groupby('Price_Range')['Sales'].mean()

# Display the results
print(sales_by_price_range)
# Out:
# Price_Range
# 0-100       2474.693286
# 101-200     8076.359736
# 201-300    12264.088112
# 301-400    17320.632682
# 401-500    24369.415000
# 501+                NaN
# Name: Sales, dtype: float64
# C:\Users\Dell\AppData\Local\Temp\ipykernel_15436\1287650806.py:9: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   sales_by_price_range = data_cleaned.groupby('Price_Range')['Sales'].mean()

# %%
# Create the bar plot
plt.figure(figsize=(10, 6))
ax = sns.barplot(x=sales_by_price_range.index, y=sales_by_price_range.values, color='lightblue')

# Add titles and labels
plt.title("Average Sales by Price Range", fontsize=14)
plt.xlabel("Price Range", fontsize=12)
plt.ylabel("Average Sales", fontsize=12)

# Display values on top of each bar
for p in ax.patches:
    ax.annotate(f'{p.get_height():,.0f}', 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='center', 
                fontsize=12, color='black', 
                xytext=(0, 5), textcoords='offset points')

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Ensure 'Date' is in datetime format
data_cleaned['Date'] = pd.to_datetime(data_cleaned['Date'])

# Extract Month and Day of the Week from Date
data_cleaned['Month'] = data_cleaned['Date'].dt.month
data_cleaned['Day_of_Week'] = data_cleaned['Date'].dt.day_name()

# Group by Month and calculate the average sales for each month
sales_by_month = data_cleaned.groupby('Month')['Sales'].mean()

# Group by Day of the Week and calculate the average sales for each day
sales_by_day = data_cleaned.groupby('Day_of_Week')['Sales'].mean()

# Plotting the results
plt.figure(figsize=(12, 6))

# Plot sales by month
plt.subplot(1, 2, 1)
ax1 = sales_by_month.plot(kind='bar', color='lightblue')

# Set x-tick labels to month names
ax1.set_xticklabels(pd.to_datetime(sales_by_month.index, format='%m').month_name(), rotation=45)

plt.title('Average Sales by Month')
plt.xlabel('Month')
plt.ylabel('Average Sales')

# Plot sales by day of the week
plt.subplot(1, 2, 2)
sales_by_day = sales_by_day[['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']]  # Sort days in order
ax2 = sales_by_day.plot(kind='bar', color='lightgreen')
plt.title('Average Sales by Day of the Week')
plt.xlabel('Day of the Week')
plt.ylabel('Average Sales')

# Show the plot
plt.tight_layout()
plt.show()

# %%
#Analyzing the relationship between product prices and sales volume can provide valuable insights into how pricing impacts sales performance. Based on the correlation, trends, and distribution of the data, here are some key insights you can explore:

#1. Price and Sales Correlation
#Negative Correlation: If you find a negative correlation (e.g., around -0.5 or lower), it indicates that as the price increases, the sales volume tends to decrease. This could suggest that consumers are price-sensitive and prefer lower-priced products. It might also indicate that higher prices are associated with more premium or less frequently purchased items.
#Positive Correlation: A positive correlation (e.g., close to 0.5 or higher) suggests that as the price increases, sales also increase. This might happen if higher-priced products are seen as more valuable or if the market is less sensitive to price increases, potentially due to higher income groups or luxury items.
#No Correlation: A weak or zero correlation suggests there is no significant linear relationship between price and sales volume, meaning that price may not be a deciding factor in purchasing behavior for this product.

# %%
#3. Dynamic Pricing Strategy:
#If the dataset indicates fluctuations in sales volume during certain periods (e.g., seasonal variations), implementing a dynamic pricing strategy might be effective.
#Strategy: Adjust prices based on external factors like seasonality, demand fluctuations, or market conditions. For example, increase prices during high-demand periods (e.g., holiday seasons, Black Friday) and offer discounts or promotions during off-peak times to stimulate demand.
#Action: Use data analytics and predictive models to forecast demand and price elasticity for each product during different time periods.
#Goal: Capture higher margins during peak seasons and increase sales volume during off-peak seasons by offering discounts or limited-time offers.
# Premium Pricing Strategy:
#If the analysis shows that higher prices correlate with relatively stable or increasing sales (suggesting a premium segment), it suggests there is a market for luxury or high-value products.
#Strategy: For high-end products or items with a unique selling proposition (USP), you should adopt a premium pricing model. This allows you to charge a higher price based on the perceived value of the product (e.g., high quality, exclusivity, or advanced features).
#Action: Highlight the premium features of the product (e.g., craftsmanship, brand image, innovation) through advertising and branding efforts.
#goal: Maximize profit margins by selling to customers who value the exclusivity or higher quality, while maintaining lower sales volume but higher revenue per unit.
